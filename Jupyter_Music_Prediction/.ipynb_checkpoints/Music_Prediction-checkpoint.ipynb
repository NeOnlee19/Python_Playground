# %%
import pandas as pd
music_data = pd.read_csv("music.csv")
music_data.drop(columns=["genre"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30268\2231816389.py in ?()
#       1 import pandas as pd
#       2 music_data = pd.read_csv("music.csv")
# ----> 3 music_data.drop()
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5599                 weight  250.0   150.0
#    5600         falcon  speed   320.0   250.0
#    5601                 weight  1.0     0.8
#    5602         """
# -> 5603         return super().drop(
#    5604             labels=labels,
#    5605             axis=axis,
#    5606             index=index,
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4798             axes = {"index": index}
#    4799             if self.ndim == 2:
# ...
